# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
import random
import cv2

# %%
import os
import tensorflow as tf
from tqdm import tqdm

# %% [markdown]
# # Importing the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
good_frames = '/content/drive/MyDrive/mini_clean'

# %%
bad_frames = '/content/drive/MyDrive/mini_blur'

# %%
clean_frames = []
for file in tqdm(sorted(os.listdir(good_frames))):
  if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
    image = tf.keras.preprocessing.image.load_img(good_frames + '/' + file, target_size=(128,128))
    image = tf.keras.preprocessing.image.img_to_array(image).astype('float32') / 255
    clean_frames.append(image)

clean_frames = np.array(clean_frames)
# Out:
# 100%|██████████| 51/51 [00:01<00:00, 26.34it/s]

# %%
blurry_frames = []
for file in tqdm(sorted(os.listdir(bad_frames))):
  if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
    image = tf.keras.preprocessing.image.load_img(bad_frames + '/' + file, target_size=(128,128))
    image = tf.keras.preprocessing.image.img_to_array(image).astype('float32') / 255
    blurry_frames.append(image)

blurry_frames = np.array(blurry_frames)
# Out:
# 100%|██████████| 51/51 [00:01<00:00, 33.44it/s]

# %% [markdown]
# # Importing Libraries for the Model

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Dense, Input
from keras.layers import Conv2D, Flatten
from keras.layers import Reshape, Conv2DTranspose
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.datasets import cifar10
from keras.utils.vis_utils import plot_model
from keras import backend as K

seed = 2019
random.seed = seed
np.random.seed = seed

# %% [markdown]
# # Splitting the Dataset into Training and Testing sets

# %%
# split = int((len(clean_frames)*80)/100)

# %%
# x_train = blurry_frames[:split] 
# y_train = clean_frames[:split]
# x_test  = blurry_frames[split:]
# y_test  = clean_frames[split:]

# %%
x = clean_frames;
y = blurry_frames;

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train[0].shape)
print(y_train[0].shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)

# %%
r = random.randint(0, len(clean_frames)-1)
print(r)
fig = plt.figure()
fig.subplots_adjust(hspace=0.1, wspace=0.2)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(clean_frames[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(blurry_frames[r])
# Out:
# 40

# %%
# Network Parameters
input_shape = (128, 128, 3)
batch_size = 32
kernel_size = 3
latent_dim = 256

# Encoder/Decoder number of CNN layers and filters per layer
layer_filters = [64, 128, 256]

# %% [markdown]
# # Encoder Model

# %%
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
# Stack of Conv2D(64)-Conv2D(128)-Conv2D(256)
for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=2,
               activation='relu',
               padding='same')(x)
# shape info needed to build decoder model so we don't do hand computation
# the input to the decoder's first Conv2DTranspose will have this shape
# shape is (4, 4, 256) which is processed by the decoder back to (32, 32, 3)
shape = K.int_shape(x)

# Generate a latent vector
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)

# Instantiate encoder model
encoder = Model(inputs, latent, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        1792
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               16777472
# =================================================================
# Total params: 17,148,288
# Trainable params: 17,148,288
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Decoder Model

# %%
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)

# Stack of Conv2DTranspose(256)-Conv2DTranspose(128)-Conv2DTranspose(64)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        strides=2,
                        activation='relu',
                        padding='same')(x)

outputs = Conv2DTranspose(filters=3,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 256)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 65536)             16842752
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 64, 64, 128)       295040
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 128, 128, 64)      73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 3)       1731
# =================================================================
# Total params: 17,803,395
# Trainable params: 17,803,395
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Autoencoder Model = Encoder Model + Decoder Model

# %%
# instantiate autoencoder model
autoencoder = Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               17148288
# _________________________________________________________________
# decoder (Functional)         (None, 128, 128, 3)       17803395
# =================================================================
# Total params: 34,951,683
# Trainable params: 34,951,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# %%
import math
from keras import backend as K

def PSNR(y_true, y_pred):
    max_pixel = 1.0
    return (10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true), axis=-1)))) / 2.303

# %%
# Mean Square Error (MSE) loss function, Adam optimizer
autoencoder.compile(loss='mse', optimizer='adam',metrics=[PSNR])

# %%
# Calling every epoch
callbacks = [lr_reducer]

# %% [markdown]
# # Training the Autoencoder

# %%
history = autoencoder.fit(blurry_frames,
                clean_frames,
                validation_data=(blurry_frames, clean_frames),
                # validation_split=0.5,
                epochs=200,
                batch_size=batch_size,
                callbacks=callbacks)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0643 - PSNR: 15.2365 - val_loss: 0.0639 - val_PSNR: 15.2668
# Epoch 2/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0638 - PSNR: 15.2729 - val_loss: 0.0632 - val_PSNR: 15.3154
# Epoch 3/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0631 - PSNR: 15.3274 - val_loss: 0.0624 - val_PSNR: 15.3836
# Epoch 4/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0622 - PSNR: 15.4009 - val_loss: 0.0613 - val_PSNR: 15.4699
# Epoch 5/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0611 - PSNR: 15.4922 - val_loss: 0.0603 - val_PSNR: 15.5684
# Epoch 6/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0602 - PSNR: 15.5704 - val_loss: 0.0599 - val_PSNR: 15.6763
# Epoch 7/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0597 - PSNR: 15.7037 - val_loss: 0.0593 - val_PSNR: 15.8158
# Epoch 8/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0594 - PSNR: 15.7356 - val_loss: 0.0576 - val_PSNR: 15.7759
# Epoch 9/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0573 - PSNR: 15.7916 - val_loss: 0.0539 - val_PSNR: 16.1584
# Epoch 10/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0561 - PSNR: 16.0507 - val_loss: 0.0586 - val_PSNR: 15.8809
# Epoch 11/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0588 - PSNR: 15.7650 - val_loss: 0.0563 - val_PSNR: 15.7853
# Epoch 12/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0569 - PSNR: 15.7459 - val_loss: 0.0579 - val_PSNR: 15.7053
# Epoch 13/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0579 - PSNR: 15.7027 - val_loss: 0.0583 - val_PSNR: 15.7114
# Epoch 14/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0579 - PSNR: 15.7345 - val_loss: 0.0563 - val_PSNR: 15.8394
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# Epoch 15/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.
100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0137 - PSNR: 22.9984 - val_loss: 0.0134 - val_PSNR: 23.0954
# Epoch 84/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0135 - PSNR: 23.0811 - val_loss: 0.0133 - val_PSNR: 23.1972
# Epoch 85/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0133 - PSNR: 23.1416 - val_loss: 0.0131 - val_PSNR: 23.2320
# Epoch 86/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0131 - PSNR: 23.2129 - val_loss: 0.0129 - val_PSNR: 23.3150
# Epoch 87/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0129 - PSNR: 23.2816 - val_loss: 0.0128 - val_PSNR: 23.2723
# Epoch 88/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0128 - PSNR: 23.3130 - val_loss: 0.0126 - val_PSNR: 23.4364
# Epoch 89/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0126 - PSNR: 23.4232 - val_loss: 0.0125 - val_PSNR: 23.3577
# Epoch 90/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0125 - PSNR: 23.4051 - val_loss: 0.0124 - val_PSNR: 23.4941
# Epoch 91/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0124 - PSNR: 23.5085 - val_loss: 0.0123 - val_PSNR: 23.4019
# Epoch 92/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0122 - PSNR: 23.4521 - val_loss: 0.0122 - val_PSNR: 23.5877
# Epoch 93/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0121 - PSNR: 23.6043 - val_loss: 0.0120 - val_PSNR: 23.4968
# Epoch 94/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0120 - PSNR: 23.5460 - val_loss: 0.0119 - val_PSNR: 23.7245
# Epoch 95/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0119 - PSNR: 23.7374 - val_loss: 0.0117 - val_PSNR: 23.6629
# Epoch 96/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0117 - PSNR: 23.6795 - val_loss: 0.0116 - val_PSNR: 23.8392
# Epoch 97/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0116 - PSNR: 23.8286 - val_loss: 0.0115 - val_PSNR: 23.7778
# Epoch 98/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0115 - PSNR: 23.7852 - val_loss: 0.0113 - val_PSNR: 23.9221
# Epoch 99/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0113 - PSNR: 23.9272 - val_loss: 0.0113 - val_PSNR: 23.8806
# Epoch 100/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0112 - PSNR: 23.8657 - val_loss: 0.0111 - val_PSNR: 23.9690

# %% [markdown]
# # Final Result

# %%
print("\n       Input                        Ground Truth                  Predicted Value")
for i in range(3):
    
    r = random.randint(0, len(clean_frames)-1)

    x, y = blurry_frames[r],clean_frames[r]
    x_inp=x.reshape(1,128,128,3)
    result = autoencoder.predict(x_inp)
    result = result.reshape(128,128,3)

    fig = plt.figure(figsize=(12,10))
    fig.subplots_adjust(hspace=0.1, wspace=0.2)

    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(x)

    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(y)

    ax = fig.add_subplot(1, 3, 3)
    plt.imshow(result)
# Out:
#        Input                        Ground Truth                  Predicted Value

# %% [markdown]
# # Testing Accuracy

# %%
testLoss, testAccuracy = autoencoder.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0059 - PSNR: 29.2501

# %%
print("Testing Loss: ", testLoss)
print("Testing Accuracy: ", testAccuracy)
# Out:
# Testing Loss:  0.5931310653686523
# Testing Accuracy:  0.7205810546875

# %% [markdown]
# #Analysis

# %%
from skimage.metrics import peak_signal_noise_ratio

# predicted_images = inference_batch_images(model, noisy_test_images)
psnr_original_mean = 0
psnr_prediction_mean = 0

for gt_img, blurry_img, predicted_img in zip(x, y, result):
    psnr_original_mean += peak_signal_noise_ratio(gt_img, blurry_img)
    psnr_prediction_mean += peak_signal_noise_ratio(gt_img, predicted_img)

psnr_original_mean/=x.shape[0]
psnr_prediction_mean/=x.shape[0]
print("Original average  PSNR: ", psnr_original_mean)
print("Predicted average  PSNR: ", psnr_prediction_mean)
# Out:
# Original average  PSNR:  21.2320991639345
# Predicted average  PSNR:  21.80408771708922

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Test'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(np.arange(0, 101, 25))
plt.show()

plt.figure(figsize=(12,8))
plt.plot(history.history['PSNR'])
plt.plot(history.history['val_PSNR'])
plt.legend(['Train', 'Test'])
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.xticks(np.arange(0, 101, 25))
plt.show()
